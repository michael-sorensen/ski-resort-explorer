# %%
import requests
import pandas as pd
import json
from pprint import pprint
from bs4 import BeautifulSoup
import urllib.parse
import numpy as np

# %%
urls = []
base = "https://www.skiresort.info/ski-resorts/africa"

            

url = base
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
resorts_div = soup.findAll('a', class_='h3')
for elm in resorts_div:
    urls.append(elm.get('href'))

# %%
urls
# Out:
# ['https://www.skiresort.info/ski-resort/oukaimeden/',
#  'https://www.skiresort.info/ski-resort/chrea/',
#  'https://www.skiresort.info/ski-resort/afriski-mountain-resort/',
#  'https://www.skiresort.info/ski-resort/tiffindell/',
#  'https://www.skiresort.info/ski-resort/michlifen/',
#  'https://www.skiresort.info/ski-resort/ski-egypt/',
#  'https://www.skiresort.info/ski-resort/matroosberg/',
#  'https://www.skiresort.info/ski-resort/jbel-hebri/',
#  'https://www.skiresort.info/ski-resort/snow-city-egypt-cairo/',
#  'https://www.skiresort.info/ski-resort/ski-namibia/',
#  'https://www.skiresort.info/ski-resort/snowfun-cape-town-planned/',
#  'https://www.skiresort.info/ski-resort/rif-gebirge/',
#  'https://www.skiresort.info/ski-resort/djebel-bou-iblane/',
#  'https://www.skiresort.info/ski-resort/kitzsteinhornmaiskogel-kaprun/test-report/',
#  'https://www.skiresort.info/ski-resort/rosskopf-monte-cavallo-sterzing-vipiteno/test-report/',
#  'https://www.skiresort.info/ski-resort/soelden/snow-report/',
#  'https://www.skiresort.info/ski-resort/kitzsteinhornmaiskogel-kaprun/snow-report/',
#  'https://www.skiresort.info/ski-resort/obertauern/photos/',
#  'https://www.skiresort.info/ski-resort/kaltenbach-hochzillertalhochfuegen-ski-optimal/photos/',
#  'https://www.skiresort.info/ski-resort/arosa-lenzerheide/',
#  'https://www.skiresort.info/ski-resort/arosa-lenzerheide/webcams/',
#  'https://www.skiresort.info/ski-resort/obertauern/webcams/',
#  'https://www.skiresort.info/ski-resort/kitzski-kitzbuehelkirchberg/trail-map/',
#  'https://www.skiresort.info/ski-resort/arosa-lenzerheide/trail-map/',
#  'https://www.skiresort.info/ski-resort/racines-giovo-ratschings-jaufenmalga-calice-kalcheralm/trail-map/',
#  'https://www.skiresort.info/ski-resort/biberwier-marienberg/trail-map/',
#  'https://www.skiresort.info/ski-resort/belpiano-schoenebenmalga-san-valentino-haideralm/test-report/',
#  'https://www.skiresort.info/ski-resort/ski-juwel-alpbachtal-wildschoenau/test-report/',
#  'https://www.skiresort.info/ski-resort/carezza-ski/snow-report/',
#  'https://www.skiresort.info/ski-resort/saalbach-hinterglemm-leogang-fieberbrunn-skicircus/snow-report/',
#  'https://www.skiresort.info/ski-resort/st-jakob-im-defereggental-brunnalm/test-result/families-children/']

# %%
urls[:] = [x for x in urls if "report" not in x]
urls[:] = [x for x in urls if "result" not in x]
urls[:] = [x for x in urls if "webcams" not in x]
urls[:] = [x for x in urls if "photos" not in x]
urls[:] = [x for x in urls if "trail-map" not in x]
urls[:] = [x for x in urls if "arosa" not in x]
print(len(urls))
# Out:
# 13

# %%
urls
# Out:
# ['https://www.skiresort.info/ski-resort/oukaimeden/',
#  'https://www.skiresort.info/ski-resort/chrea/',
#  'https://www.skiresort.info/ski-resort/afriski-mountain-resort/',
#  'https://www.skiresort.info/ski-resort/tiffindell/',
#  'https://www.skiresort.info/ski-resort/michlifen/',
#  'https://www.skiresort.info/ski-resort/ski-egypt/',
#  'https://www.skiresort.info/ski-resort/matroosberg/',
#  'https://www.skiresort.info/ski-resort/jbel-hebri/',
#  'https://www.skiresort.info/ski-resort/snow-city-egypt-cairo/',
#  'https://www.skiresort.info/ski-resort/ski-namibia/',
#  'https://www.skiresort.info/ski-resort/snowfun-cape-town-planned/',
#  'https://www.skiresort.info/ski-resort/rif-gebirge/',
#  'https://www.skiresort.info/ski-resort/djebel-bou-iblane/']

# %%
resort_dictionary = {}
resort_data = []
test_urls = ['https://www.skiresort.info/ski-resort/sky-mountain-beidahu/', 'https://www.skiresort.info/ski-resort/crested-butte/',  'https://www.skiresort.info/ski-resort/erciyes-kayseri/','https://www.skiresort.info/ski-resort/myoko-suginohara/', 'https://www.skiresort.info/ski-resort/kiroro/',  'https://www.skiresort.info/ski-resort/hachikogenhachi-kita-kogen/','https://www.skiresort.info/ski-resort/aomori-spring/', 'https://www.skiresort.info/ski-resort/niki-chomin/','https://www.skiresort.info/ski-resort/muroran-kogen-danpara/','https://www.skiresort.info/ski-resort/yunotani-yakushi/','https://www.skiresort.info/ski-resort/ushidake-onsen/','https://www.skiresort.info/ski-resort/akan-royal-valley/','https://www.skiresort.info/ski-resort/akitaken-tazawako/']
failed_links = []

for url in urls:
    try:
        r = requests.get(url)
        soup = BeautifulSoup(r.text, 'html.parser')
        s = soup.find('div', class_='panel-simple more-padding')
        im = soup.find('div', class_='panel-image')

        # basic data -----------------------------------------------
        name = s.find('p', class_='bodytext').get_text()
        description = s.findAll('p')[1].get_text()

        # elevation -----------------------------------------------
        alt = s.find('div', class_='description').get_text()
        elevation_base = alt.split(' m', 1)[0]
        elevation_testing = alt.split('m - ', 1)[1]
        elevation_summit = elevation_testing.split(' m ', 1)[0]

        # images -----------------------------------------------
        try:
            img_url = im.find('a').get('href')
            full_img_url = f'https://www.skiresort.info/{img_url}'
        except:
            full_img_url="n/a"

        r2 = requests.get(f"{url}/trail-map/")
        soup2 = BeautifulSoup(r2.text, 'html.parser')
        try:
            map_url = soup2.find('div', class_='mobile-trailmap-image').find('a').get('href')
            full_map_url = f'https://www.skiresort.info/{map_url}'
        except:
            full_map_url="n/a"


        # runs -----------------------------------------------
        runs = str(s.findAll('div', class_='description')[1])
        runs_total = str(s.findAll('div', class_='description')[1].find(id='selSlopetot').get_text())
        runs_testing = runs_total.split('al: ', 1)[1]
        runs_total2=runs_testing.split(' k', 1)[0]
        try:
            runs_green_testing = runs.split('ner">', 1)[1]
            runs_green = runs_green_testing.split(' km', 1)[0]
        except:
            runs_green=0
        try:
            runs_blue_testing = runs.split('Inter">', 1)[1]
            runs_blue = runs_blue_testing.split(' km', 1)[0]
        except:
            runs_blue=0

        try:
            runs_black_testing = runs.split('Adv">', 1)[1]
            runs_black = runs_black_testing.split(' km', 1)[0]
        except:
            runs_black=0



        # lat & lng -----------------------------------------------
        r3 = requests.get(f"{url}hotels-accommodations/")
        soup3 = BeautifulSoup(r3.text, 'html.parser')
        latlng = soup3.find('div', class_='search-hotel').find('div', class_='stay22trivago')
        latlng_link = latlng.findAll('optgroup')[1].find('option').get('value')
        try:
            lat_testing = latlng_link.split('lat=', 1)[1]
            lat2 = str(lat_testing.split('&', 1)[0])
            lng_testing = latlng_link.split('lng=', 1)[1]
            lng2 = str(lng_testing.split('&', 1)[0])
        except:
            print("error")

        # lifts -----------------------------------------------
        lifts = str(s.findAll('div', class_='lift-count'))
        lifts_total = str(s.find('div', class_='lift-info-group').find(id='selLiftstot'))
        lifts_testing = lifts_total.split('al: ', 1)[1]
        lifts_total2=lifts_testing.split('<', 1)[0]
        try:
            lifts_by_1 = s.find('div', attrs={'title':'Chairlift'})
            chairlifts = int(lifts_by_1.find('span', class_='lift-amount').get_text())
        except:
            chairlifts=0

        try:
            lifts_by_2 = s.find('div', attrs={'title':'Circulating ropeway/gondola lift'})
            gondola = int(lifts_by_2.find('span', class_='lift-amount').get_text())
        except:
            gondolas=0

        try:
            lifts_by_3 = s.find('div', attrs={'title':'Aerial tramway/reversible ropeway'})
            trams = int(lifts_by_3.find('span', class_='lift-amount').get_text())
        except:
            trams=0

        try:
            lifts_by_4 = s.find('div', attrs={'title':'Combined installation (gondola and chair)'})
            combo = int(lifts_by_4.find('span', class_='lift-amount').get_text())
        except:
            combo=0

        try:
            lifts_by_5 = s.find('div', attrs={'title':'T-bar lift/platter/button lift '})
            surface = int(lifts_by_5.find('span', class_='lift-amount').get_text())
            print(surface)
        except:
            surface=0

        try:
            lifts_by_6 = s.find('div', attrs={'title':'Rope tow/baby lift'})
            ropetow = int(lifts_by_6.find('span', class_='lift-amount').get_text())
            print(ropetow)
        except:
            ropetow=0

        try:
            lifts_by_7 = s.find('div', attrs={'title':'People mover'})
            pplmover = int(lifts_by_7.find('span', class_='lift-amount').get_text())
        except:
            pplmover=0

        try:
            lifts_by_8 = s.find('div', attrs={'title':'Funicular'})
            funicular = lifts_by_8.find('span', class_='lift-amount').get_text()
        except:
            funicular=0

        try:
            lifts_by_9 = s.find('div', attrs={'title':'Cog railway'})
            railway = int(lifts_by_9.find('span', class_='lift-amount').get_text())
        except:
            railway=0

        gdtr=gondolas+trams+combo
        surface_lifts = surface+ropetow+pplmover
        trains = funicular+railway

        # dictionary creation  -----------------------------------------------
        resort_dictionary = {
                "name":name,
                "image_url": full_img_url,
                "lat":lat2,
                "lng":lng2,
                "description":description,
                "lift_breakdown":{
                    "gondolasAndTrams":gdtr,
                    "trains":trains,
                    "chairlifts":chairlifts,
                    "surface":surface_lifts
                },
                "lifts_total":lifts_total2,
                "runs_total":runs_total2,
                "runsGreen_total":runs_green,
                "runsBlue_total":runs_blue,
                "runsBlack_total":runs_black,
                "elevation_base":elevation_base,
                "elevation_summit":elevation_summit,
                "trailMap_image":full_map_url
            }
        resort_data.append(resort_dictionary)
    except:
        failed_links.append(url)
        print('error')
# Out:
# 6
# 1
# 1
# 1
# 2
# 3
# 2
# 1
# 2
# error
# error
# error
# error

# %%
resort_data
# Out:
# [{'name': 'Skiing Oukaïmeden',
#   'image_url': 'n/a',
#   'lat': '31.194752',
#   'lng': '-7.855196',
#   'description': 'The ski resort Oukaïmeden is located in the Marrakesh-Tensift-El Haouz Region (Morocco). For skiing and snowboarding, there are 10 km of slopes available. 7 lifts transport the guests. The winter sports area is situated between the elevations of 2,610 and 3,268 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 1,
#    'surface': 6},
#   'lifts_total': '7',
#   'runs_total': '10',
#   'runsGreen_total': '5',
#   'runsBlue_total': '3',
#   'runsBlack_total': '2',
#   'elevation_base': ' 2610',
#   'elevation_summit': '3268',
#   'trailMap_image': 'n/a'},
#  {'name': 'Skiing Chréa',
#   'image_url': 'n/a',
#   'lat': '36.429363',
#   'lng': '2.8833',
#   'description': 'The ski resort Chréa is located in the Province of Blida (Algeria). For skiing and snowboarding, there are 0.5 km of slopes available. 3 lifts transport the guests. The winter sports area is situated between the elevations of 1,460 and 1,550 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 1},
#   'lifts_total': '3',
#   'runs_total': '0.5',
#   'runsGreen_total': '0.3',
#   'runsBlue_total': '0.2',
#   'runsBlack_total': '0',
#   'elevation_base': ' (212',
#   'elevation_summit': '1550',
#   'trailMap_image': 'n/a'},
#  {'name': 'Skiing Afriski Mountain Resort',
#   'image_url': 'https://www.skiresort.info/typo3temp/_processed_/d5/57/72/2f/c322761282.jpg',
#   'lat': '-28.822314',
#   'lng': '28.726029',
#   'description': 'The ski resort Afriski Mountain Resort is located in the Butha-Buthe District (Lesotho). For skiing and snowboarding, there are 1.8 km of slopes available. 2 lifts transport the guests. The winter sports area is situated between the elevations of 3,030 and 3,222 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 5},
#   'lifts_total': '2',
#   'runs_total': '1.8',
#   'runsGreen_total': '0.2',
#   'runsBlue_total': '0.6',
#   'runsBlack_total': '1',
#   'elevation_base': ' 3030',
#   'elevation_summit': '3222',
#   'trailMap_image': 'https://www.skiresort.info/typo3temp/assets/_processed_/13/37/79/92/93d10aa92a.jpg'},
#  {'name': 'Skiing Tiffindell',
#   'image_url': 'n/a',
#   'lat': '-30.653165',
#   'lng': '27.927203',
#   'description': 'The ski resort Tiffindell is located in the Province of Eastern Cape (South Africa). For skiing and snowboarding, there are 2.4 km of slopes available. 5 lifts transport the guests. The winter sports area is situated between the elevations of 2,700 and 2,930 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 5},
#   'lifts_total': '5',
#   'runs_total': '2.4',
#   'runsGreen_total': '0.6',
#   'runsBlue_total': '0.8',
#   'runsBlack_total': '1',
#   'elevation_base': ' 2700',
#   'elevation_summit': '2930',
#   'trailMap_image': 'https://www.skiresort.info/typo3temp/assets/_processed_/05/5f/f5/5b/288ba996ba.jpg'},
#  {'name': 'Skiing Michlifen',
#   'image_url': 'n/a',
#   'lat': '33.412469',
#   'lng': '-5.080581',
#   'description': 'The ski resort Michlifen is located in the Meknès-Tafilalet Region (Morocco). For skiing and snowboarding, there are 1 km of slopes available. 2 lifts transport the guests. The winter sports area is situated between the elevations of 1,880 and 2,060 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 2},
#   'lifts_total': '2',
#   'runs_total': '1',
#   'runsGreen_total': '0.6',
#   'runsBlue_total': '0.4',
#   'runsBlack_total': '0',
#   'elevation_base': ' 1880',
#   'elevation_summit': '2060',
#   'trailMap_image': 'n/a'},
#  {'name': 'Skiing Ski Egypt',
#   'image_url': 'n/a',
#   'lat': '29.972115',
#   'lng': '31.019308',
#   'description': 'The ski resort Ski Egypt is located in Egypt. For skiing and snowboarding, there are 0.6 km of slopes available. 1 lift transports the guests. The winter sports area is situated between the elevations of 150 and 180 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 1},
#   'lifts_total': '1',
#   'runs_total': '0.6',
#   'runsGreen_total': '0.5',
#   'runsBlue_total': '0',
#   'runsBlack_total': '0.1',
#   'elevation_base': ' 150',
#   'elevation_summit': '180',
#   'trailMap_image': 'n/a'},
#  {'name': 'Skiing Matroosberg',
#   'image_url': 'n/a',
#   'lat': '-33.377953',
#   'lng': '19.67209',
#   'description': 'The ski resort Matroosberg is located in the Province of Western Cape (South Africa). For skiing and snowboarding, there are 2 km of slopes available. 2 lifts transport the guests. The winter sports area is situated between the elevations of 1,794 and 2,132 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 2},
#   'lifts_total': '2',
#   'runs_total': '2',
#   'runsGreen_total': '1',
#   'runsBlue_total': '1',
#   'runsBlack_total': '0',
#   'elevation_base': ' 1794',
#   'elevation_summit': '2132',
#   'trailMap_image': 'https://www.skiresort.info/typo3temp/assets/_processed_/fa/a0/04/44/b1842ebc84.jpg'},
#  {'name': 'Skiing Jbel Hebri',
#   'image_url': 'n/a',
#   'lat': '33.364912',
#   'lng': '-5.141071',
#   'description': 'The ski resort Jbel Hebri is located in the Meknès-Tafilalet Region (Morocco). For skiing and snowboarding, there are 1 km of slopes available. 1 lift transports the guests. The winter sports area is situated between the elevations of 1,950 and 2,090 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 0},
#   'lifts_total': '1',
#   'runs_total': '1',
#   'runsGreen_total': '0',
#   'runsBlue_total': '1',
#   'runsBlack_total': '0',
#   'elevation_base': ' 1950',
#   'elevation_summit': '2090',
#   'trailMap_image': 'n/a'},
#  {'name': 'Skiing Snow City Egypt – Cairo',
#   'image_url': 'n/a',
#   'lat': '30.073483',
#   'lng': '31.347156',
#   'description': 'The ski resort Snow City Egypt – Cairo is located in Egypt. For skiing and snowboarding, there are 0.1 km of slopes available. The winter sports area is situated between the elevations of 89 and 98 m. ',
#   'lift_breakdown': {'gondolasAndTrams': 0,
#    'trains': 0,
#    'chairlifts': 0,
#    'surface': 1},
#   'lifts_total': '0',
#   'runs_total': '0.1',
#   'runsGreen_total': '0.1',
#   'runsBlue_total': '0',
#   'runsBlack_total': '0',
#   'elevation_base': ' 89',
#   'elevation_summit': '98',
#   'trailMap_image': 'n/a'}]

# %%
resort_df = pd.DataFrame(resort_data)

# %%
resort_df.head(60)
# Out:
#                              name  \
# 0               Skiing Oukaïmeden
# 1                    Skiing Chréa
# 2  Skiing Afriski Mountain Resort
# 3               Skiing Tiffindell
# 4                Skiing Michlifen
# 5                Skiing Ski Egypt
# 6              Skiing Matroosberg
# 7               Skiing Jbel Hebri
# 8  Skiing Snow City Egypt – Cairo
#
#                                            image_url         lat        lng  \
# 0                                                n/a   31.194752  -7.855196
# 1                                                n/a   36.429363     2.8833
# 2  https://www.skiresort.info/typo3temp/_processe...  -28.822314  28.726029
# 3                                                n/a  -30.653165  27.927203
# 4                                                n/a   33.412469  -5.080581
# 5                                                n/a   29.972115  31.019308
# 6                                                n/a  -33.377953   19.67209
# 7                                                n/a   33.364912  -5.141071
# 8                                                n/a   30.073483  31.347156
#
#                                          description  \
# 0  The ski resort Oukaïmeden is located in the Ma...
# 1  The ski resort Chréa is located in the Provinc...
# 2  The ski resort Afriski Mountain Resort is loca...
# 3  The ski resort Tiffindell is located in the Pr...
# 4  The ski resort Michlifen is located in the Mek...
# 5  The ski resort Ski Egypt is located in Egypt. ...
# 6  The ski resort Matroosberg is located in the P...
# 7  The ski resort Jbel Hebri is located in the Me...
# 8  The ski resort Snow City Egypt – Cairo is loca...
#
#                                       lift_breakdown lifts_total runs_total  \
# 0  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           7         10
# 1  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           3        0.5
# 2  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           2        1.8
# 3  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           5        2.4
# 4  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           2          1
# 5  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           1        0.6
# 6  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           2          2
# 7  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           1          1
# 8  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           0        0.1
#
#   runsGreen_total runsBlue_total runsBlack_total elevation_base  \
# 0               5              3               2           2610
# 1             0.3            0.2               0           (212
# 2             0.2            0.6               1           3030
# 3             0.6            0.8               1           2700
# 4             0.6            0.4               0           1880
# 5             0.5              0             0.1            150
# 6               1              1               0           1794
# 7               0              1               0           1950
# 8             0.1              0               0             89
#
#   elevation_summit                                     trailMap_image
# 0             3268                                                n/a
# 1             1550                                                n/a
# 2             3222  https://www.skiresort.info/typo3temp/assets/_p...
# 3             2930  https://www.skiresort.info/typo3temp/assets/_p...
# 4             2060                                                n/a
# 5              180                                                n/a
# 6             2132  https://www.skiresort.info/typo3temp/assets/_p...
# 7             2090                                                n/a
# 8               98                                                n/a

# %%
resort_df['runsBlue_total'].replace('n/a', np.NaN, inplace=True)
resort_df['runsGreen_total'].replace('n/a', np.NaN, inplace=True)
resort_df['runsBlack_total'].replace('n/a', np.NaN, inplace=True)
resort_df['runs_total'].replace('n/a', np.NaN, inplace=True)
resort_df['runs_total'].replace('n/a', np.NaN, inplace=True)

# %%
resort_df['runsBlue_total'] = pd.to_numeric(resort_df['runsBlue_total'])
resort_df['runsGreen_total'] = pd.to_numeric(resort_df['runsGreen_total'])
resort_df['runsBlack_total'] = pd.to_numeric(resort_df['runsBlack_total'])
resort_df['runs_total'] = pd.to_numeric(resort_df['runs_total'])

# %%
resort_df['elevation_base'] = resort_df['elevation_base'].str.replace('(','', regex=True)

# %%
resort_df['elevation_summit'] = pd.to_numeric(resort_df['elevation_summit'])
resort_df['elevation_base'] = pd.to_numeric(resort_df['elevation_base'])

# %%
resort_df['total_runs'] = ((resort_df['runsBlue_total'])+(resort_df['runsGreen_total'])+(resort_df['runsBlack_total']))
resort_df['runsBlue_percent'] = (resort_df['runsBlue_total'])/(resort_df['total_runs'])*100
resort_df['runsGreen_percent'] = (resort_df['runsGreen_total'])/(resort_df['total_runs'])*100
resort_df['runsBlack_percent'] = (resort_df['runsBlack_total'])/(resort_df['total_runs'])*100

# %%
resort_df['vertical_drop'] =(resort_df['elevation_summit'])-(resort_df['elevation_base'])

# %%
resort_df.to_json('resorts_africa.json')

# %%
resort_df
# Out:
#                              name  \
# 0               Skiing Oukaïmeden
# 1                    Skiing Chréa
# 2  Skiing Afriski Mountain Resort
# 3               Skiing Tiffindell
# 4                Skiing Michlifen
# 5                Skiing Ski Egypt
# 6              Skiing Matroosberg
# 7               Skiing Jbel Hebri
# 8  Skiing Snow City Egypt – Cairo
#
#                                            image_url         lat        lng  \
# 0                                                n/a   31.194752  -7.855196
# 1                                                n/a   36.429363     2.8833
# 2  https://www.skiresort.info/typo3temp/_processe...  -28.822314  28.726029
# 3                                                n/a  -30.653165  27.927203
# 4                                                n/a   33.412469  -5.080581
# 5                                                n/a   29.972115  31.019308
# 6                                                n/a  -33.377953   19.67209
# 7                                                n/a   33.364912  -5.141071
# 8                                                n/a   30.073483  31.347156
#
#                                          description  \
# 0  The ski resort Oukaïmeden is located in the Ma...
# 1  The ski resort Chréa is located in the Provinc...
# 2  The ski resort Afriski Mountain Resort is loca...
# 3  The ski resort Tiffindell is located in the Pr...
# 4  The ski resort Michlifen is located in the Mek...
# 5  The ski resort Ski Egypt is located in Egypt. ...
# 6  The ski resort Matroosberg is located in the P...
# 7  The ski resort Jbel Hebri is located in the Me...
# 8  The ski resort Snow City Egypt – Cairo is loca...
#
#                                       lift_breakdown lifts_total  runs_total  \
# 0  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           7        10.0
# 1  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           3         0.5
# 2  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           2         1.8
# 3  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           5         2.4
# 4  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           2         1.0
# 5  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           1         0.6
# 6  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           2         2.0
# 7  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           1         1.0
# 8  {'gondolasAndTrams': 0, 'trains': 0, 'chairlif...           0         0.1
#
#    runsGreen_total  runsBlue_total  runsBlack_total  elevation_base  \
# 0              5.0             3.0              2.0            2610
# 1              0.3             0.2              0.0             212
# 2              0.2             0.6              1.0            3030
# 3              0.6             0.8              1.0            2700
# 4              0.6             0.4              0.0            1880
# 5              0.5             0.0              0.1             150
# 6              1.0             1.0              0.0            1794
# 7              0.0             1.0              0.0            1950
# 8              0.1             0.0              0.0              89
#
#    elevation_summit                                     trailMap_image  \
# 0              3268                                                n/a
# 1              1550                                                n/a
# 2              3222  https://www.skiresort.info/typo3temp/assets/_p...
# 3              2930  https://www.skiresort.info/typo3temp/assets/_p...
# 4              2060                                                n/a
# 5               180                                                n/a
# 6              2132  https://www.skiresort.info/typo3temp/assets/_p...
# 7              2090                                                n/a
# 8                98                                                n/a
#
#    total_runs  runsBlue_percent  runsGreen_percent  runsBlack_percent  \
# 0        10.0         30.000000          50.000000          20.000000
# 1         0.5         40.000000          60.000000           0.000000
# 2         1.8         33.333333          11.111111          55.555556
# 3         2.4         33.333333          25.000000          41.666667
# 4         1.0         40.000000          60.000000           0.000000
# 5         0.6          0.000000          83.333333          16.666667
# 6         2.0         50.000000          50.000000           0.000000
# 7         1.0        100.000000           0.000000           0.000000
# 8         0.1          0.000000         100.000000           0.000000
#
#    vertical_drop
# 0            658
# 1           1338
# 2            192
# 3            230
# 4            180
# 5             30
# 6            338
# 7            140
# 8              9

# %%
with open('resorts_africa.json', 'w', encoding='utf-8') as file:
    resort_df.to_json(file, orient='records', indent=2, force_ascii=False)
